# %% [markdown]
# <a href="https://colab.research.google.com/github/yagamifxr-max/awesome-github-profile-readme/blob/master/untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
learned python

# %%
a+a=2
b=3
c=a+b
print (c)
